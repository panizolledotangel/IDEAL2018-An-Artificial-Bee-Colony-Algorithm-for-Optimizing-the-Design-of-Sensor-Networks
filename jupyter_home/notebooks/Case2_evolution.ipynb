# %%
# set working dir
import os
os.chdir('/home/jupyter/host_data/')

# MongoDB
import pymongo
from sources.mongo_connection.mongo_connector import MongoDBConnection

# plotting 
from sources.plotting.plotting import plot_historic_cost
from sources.plotting.metrics import max_mean_std

MongoDBConnection.initialize_connection('db', 27017)
dataset_name = "case_2"

# %% [markdown]
# # Same_1:
# "numb_bees": 50,
# "max_itrs": 200,
# "max_trials": 3600,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "same_1"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (2008.9280470000003, 2588.136238266666, 382.43210125230155)

# %% [markdown]
# # Same_2:
# "numb_bees": 50,
# "max_itrs": 200,
# "max_trials": 2500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "same_2"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1589.4241360000003, 2445.5322782333337, 461.7252055031578)

# %% [markdown]
# # Same_5:
# "numb_bees": 50,
# "max_itrs": 200,
# "max_trials": 2000,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "same_5"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1573.151869, 2589.020611566666, 436.60158144133806)

# %% [markdown]
# # Same_3:
# "numb_bees": 50,
# "max_itrs": 200,
# "max_trials": 1500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "same_3"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1611.5440470000003, 2450.7913567666674, 390.02023759833844)

# %% [markdown]
# # Same_4:
# "numb_bees": 50,
# "max_itrs": 200,
# "max_trials": 1000,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "same_4"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1715.714136, 2514.1348175000003, 369.7264957300642)

# %% [markdown]
# # Same_6:
# "numb_bees": 50,
# "max_itrs": 200,
# "max_trials": 500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "same_6"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1869.951602, 2584.7397805000005, 353.4988097694512)

# %% [markdown]
# # More iterations than pPBIL

# %% [markdown]
# # more_1 settings:
# "numb_bees": 50,
# "max_itrs": 500,
# "max_trials": 2000,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "more_1"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1170.6497800000002, 2233.1347922, 351.5297882178341)

# %% [markdown]
# # more_2 settings:
# "numb_bees": 50,
# "max_itrs": 500,
# "max_trials": 1000,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "more_2"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1440.1899580000002, 2188.965478066667, 304.93522948372924)

# %% [markdown]
# # more_3 settings:
# "numb_bees": 50,
# "max_itrs": 1000,
# "max_trials": 1500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "more_3"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1575.0861360000001, 1973.208451366667, 208.46552268748468)

# %% [markdown]
# # more_4 settings:
# "numb_bees": 50,
# "max_itrs": 1000,
# "max_trials": 2500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "more_4"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1335.0918690000003, 1877.9602351333333, 273.0502849511892)

# %% [markdown]
# # more_5 settings:
# "numb_bees": 50,
# "max_itrs": 2000,
# "max_trials": 2500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "more_5"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1350.5939580000004, 1614.4677580000002, 139.84754606694256)

# %% [markdown]
# # more_6 settings:
# "numb_bees": 50,
# "max_itrs": 2000,
# "max_trials": 1500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "more_6"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1355.9817800000003, 1731.6936868, 229.180373113726)

# %% [markdown]
# # more_7 settings:
# "numb_bees": 50,
# "max_itrs": 5000,
# "max_trials": 1500,
# "theta_min": 0.5,
# "theta_max": 0.9

# %%
settings_name = "more_7"

print(max_mean_std(dataset_name, settings_name))
plot_historic_cost("historic_evolution/cost_{0}_{1}".format(dataset_name, settings_name), 
                   "Cost Historic evolution {0}: {1}".format(dataset_name, settings_name),
                    dataset_name, settings_name, 8e3)
# Out:
# (1164.58778, 1475.6224597741939, 161.52355129576688)
